# %%
import  pandas as pd

df = pd.read_excel("C:/Users/jluci/OneDrive - datosgt.com/Escritorio/Panamerican/20. Dashboard/Base de datos.xlsx")
df.head(2)
# Out:
#        Continente                              Pais      Familia  \
# 0  Centro America  Saint Vincent and the Grenadines        Vinos
# 1          Europa                          Bulgaria  Electronica
#
#   Canal de venta Prioridad de la orden Fecha de pedido   ID Orden  \
# 0         Retail               Critica      2018-01-01  839315724
# 1     E-Commerce                  Alta      2018-01-01  799386966
#
#   Fecha de embarque  Unidades vendidas  Precio unitario  Costo unitario  \
# 0        2018-01-17                 86            50000         25000.0
# 1        2018-02-06                 53           100000         50000.0
#
#    Ventas Brutas  Total costo  Total utilidad Genero comprador  \
# 0        4300000    2150000.0       2150000.0         Femenino
# 1        5300000    2650000.0       2650000.0        Masculino
#
#   Encargado venta  Devoluciones   Año  Mes  Dia
# 0      Vendedor 2            29  2018    1    1
# 1      Vendedor 2            48  2018    1    1

# %%
# Importar librerías necesarias
import pandas as pd

# Definir la función para cargar el archivo
def Data():
    FilePath = "C:/Users/Dashboard/Base de datos.xlsx"

    if FilePath:
        try:
            if FilePath.endswith('.xlsx'):
                files = pd.read_excel(FilePath)
                display(files.head(2))
            else:
                files = pd.read_csv(FilePath)
                display(files.head(2))
            print(f"Archivo se cargado correctamente")
            return files # Retorna el DataFrame
        except Exception as e:
            print("Validar porque...", f"formto de archivo desconocido")

# definir el DataFrame
df = Data()
# Out:
#        Continente                              Pais      Familia  \
# 0  Centro America  Saint Vincent and the Grenadines        Vinos
# 1          Europa                          Bulgaria  Electronica
#
#   Canal de venta Prioridad de la orden Fecha de pedido   ID Orden  \
# 0         Retail               Critica      2018-01-01  839315724
# 1     E-Commerce                  Alta      2018-01-01  799386966
#
#   Fecha de embarque  Unidades vendidas  Precio unitario  Costo unitario  \
# 0        2018-01-17                 86            50000         25000.0
# 1        2018-02-06                 53           100000         50000.0
#
#    Ventas Brutas  Total costo  Total utilidad Genero comprador  \
# 0        4300000    2150000.0       2150000.0         Femenino
# 1        5300000    2650000.0       2650000.0        Masculino
#
#   Encargado venta  Devoluciones   Año  Mes  Dia
# 0      Vendedor 2            29  2018    1    1
# 1      Vendedor 2            48  2018    1    1
# ...

# %%
df.head(2)
# Out:
#        Continente                              Pais      Familia  \
# 0  Centro America  Saint Vincent and the Grenadines        Vinos
# 1          Europa                          Bulgaria  Electronica
#
#   Canal de venta Prioridad de la orden Fecha de pedido   ID Orden  \
# 0         Retail               Critica      2018-01-01  839315724
# 1     E-Commerce                  Alta      2018-01-01  799386966
#
#   Fecha de embarque  Unidades vendidas  Precio unitario  Costo unitario  \
# 0        2018-01-17                 86            50000         25000.0
# 1        2018-02-06                 53           100000         50000.0
#
#    Ventas Brutas  Total costo  Total utilidad Genero comprador  \
# 0        4300000    2150000.0       2150000.0         Femenino
# 1        5300000    2650000.0       2650000.0        Masculino
#
#   Encargado venta  Devoluciones   Año  Mes  Dia
# 0      Vendedor 2            29  2018    1    1
# 1      Vendedor 2            48  2018    1    1

# %%
df = pd.DataFrame(Data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20484\167652019.py in ?()
# ----> 1 df = pd.DataFrame(Data)
#
# c:\Users\jluci\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     882                 )
#     883         # For data is scalar
#     884         else:
#     885             if index is None or columns is None:
# --> 886                 raise ValueError("DataFrame constructor not properly called!")
#     887
#     888             index = ensure_index(index)
#     889             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!
